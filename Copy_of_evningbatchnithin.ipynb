# %% [markdown]
# <a href="https://colab.research.google.com/github/Allrounder07/Breast-Cancer-Detection/blob/main/Copy_of_evningbatchnithin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
print("welcome to the class Nithin")

print('2+2') #string set of characters(letters,numbers,symbols)
print(2+2) #integer

#variables=container/space memory which store data

number=90
print(numbers)

#Rules variables name shoud'tcontains the quotes
num=89
num1=89
num2=1

#Arithmatic operations
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1//num2) #non decimal values
print(num1%num2) # remainder modulo

# sting data types
fname= "Nithin"
lname= "SC"
print(fname+lname)
"""
"""
#float data types

num1=89.90
num2=1
"""
"""
2nd class
"""
"""
#rocks paper scissors
import random
print("welcome to the game")
while True:
  user=input("type rock paper scissors")
  print("you chose:",user)
  computer=random.randint(1,3)
  if computer==1:
    computer="rock"
    elif computer==2:
    computer="paper"
  else:
    computer="scissors"
    print("computer chose:",computer)
     if computer==user:
       print("draw")
"""
"""
class no 03
"""

def sleep_in(weekday,vacation):
  if not weekday or vacation:
    return True
  else:
    return False


def monkey_trouble(a_smile,b_smile):
  if a_smile and b_smile:
    return True
  elif not a_smile and not b_smile:
    return True
  else:
    return False


def sum_double(a,b):
  if a==b:
    return (a+b)*2
  else:
      return a+b


def diff21(n):
  if n>21:
    return (n-21)*2
  else:
    return 21-n

def parrot_trouble(talking,hour):
  if talking and (hour<7 or hour>20):
    return True
  else:
    return False


def parrot_trouble(talking,hour):
  if talking and (hour<7 or hour>20):
    return True
  else:
    return False

def makes10(a,b):
  if a==10 or b==10 or a+b==10:
    return True
  else:
    return False

  def near_hundred(n):
    if abs(100-n)<=10 or abs(200-n)<=10:
      return True
    else:
      return False


  def pos_neg(a,b,negative):
    if negative==True:
      if a<0 and b<0:
        return True
      else:
        return False
    else:
      if a<0 and b>0 or a>0 and b<0:
        return True
      else:
        return False


    def not_string(str):
      if str.startswith("not"):
        return str
      else:
        return "not" + str




    def front_back(str):
      if len(str) <=1:
        return str
      else:
        return str[len(str)-1] + str[1:len(str)-1] + str[0]

    def front3(str):
      return str[0:3] *3

# %%
#class 04

list=[2,3,4,5,6,7,8]
print(list)

New=int(input("enter :"))
list.append(New) #it always add at the end
print("updated list:",list)

remove_item=int(input("enter item to remove:"))
list.remove(remove_item)
print("updated list:",list)

search_item=int(input("enter item to search:"))
if search_item in list:
  print("you found")
else:
  print("not found")
'''
Make a chatbot which can do this certain task if asked add to add the elements
 till of length
 remove
 replace
 exit
 viewlist
'''


print("welcome to the game")
while True:
  # Corrected input for choice to handle string commands
  choice=input("type - add/remove/replace/viewlist/exit : ").lower() # .lower() for case-insensitivity
  if choice == 'add' : # Compare with string literal 'add'
    length=int(input("enter length of list to add:")) # Clarified prompt
    for i in range(length):
      item=input(f"enter item {i+1} to add:") # Use f-string for better prompt
      list.append(item)
    print("updated List : ",list)
  elif choice == 'remove' : # Compare with string literal 'remove'
    remove_item=input("enter item to remove:") # Input as string, then try to convert if needed, or remove by value
    if remove_item in list:
      list.remove(remove_item)
      print("updated list:",list)
    else:
      print("Item not found in list.")
  elif choice == 'replace' : # Compare with string literal 'replace'
    old_value = input("enter item to replace:") # Get old value as string
    if old_value in list:
      new_value = input("enter new value:") # Get new value as string
      # Find all occurrences and replace them
      for i in range(len(list)):
        if list[i] == old_value:
          list[i] = new_value
      print("updated list:",list)
    else:
      print("Item to replace not found in list.")
  elif choice == 'viewlist' : # Compare with string literal 'viewlist'
    print("Current list:", list)
  elif choice == 'exit' : # Compare with string literal 'exit'
    print("Exiting chatbot. Goodbye!")
    break
  else:
    print("invalid choice try again")


    def first_last6(num) :
      return num[0] == 6 or num[-1] == 6
# Out:
# [2, 3, 4, 5, 6, 7, 8]
# enter :7
# updated list: [2, 3, 4, 5, 6, 7, 8, 7]
# enter item to remove:7
# updated list: [2, 3, 4, 5, 6, 8, 7]
# enter item to search:6
# you found
# welcome to the game
# type - add/remove/replace/viewlist/exit : remove
# enter item to remove:5
